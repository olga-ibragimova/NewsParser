# %%
import requests
from bs4 import BeautifulSoup
import time
from datetime import datetime, timedelta

def get_fresh_hrefs(url, retries=5):
    err = ""
    while retries >= 0:
        try:
            resp = requests.get(url)
            soup = BeautifulSoup(resp.content, 'html.parser')
            items = soup.find_all('div', class_='list-item')
            hrefs = [item.find('a', itemprop='url')['href'] for item in items]
            return hrefs

        except Exception as e:
            err = e
            retries -= 1
    print(f'Ошибка при извлечении ссылок на новости: {err}. url: {url}')
    return None
    
def get_card(url, last_update, retries=5):
    err = ""
    while retries >= 0:
        try:
            resp = requests.get(url)
            soup = BeautifulSoup(resp.content, 'html.parser')
            content = soup.find('div', class_='endless__item')
            ts = content["data-pts"]
            if int(ts) > last_update:
                title = content.find('div', itemprop='headline').text
                annot = content.find('div', itemprop='description').text
                author = content.find('div', itemprop='author').find('div', itemprop='name').text.strip()
                body = content.find('div', itemprop='articleBody').text
                return {
                    'ts': int(ts),
                    'title': title,
                    'annotation': annot,
                    'body': body,
                    'author': author,
                    'url': url,
                }
            return None

        except Exception as e:
            err = e
            retries -= 1
    print(f'Ошибка при извлечении карточки новости: {err}. url: {url}')
    return None
            
def update_cards(urls, cards, last_update, retries=5):
    hrefs = []
    for url in urls:
        new_hrefs = get_fresh_hrefs(url)
        if new_hrefs:
            hrefs.extend(new_hrefs)
    
    for href in hrefs:
        if href not in cards:
            new_card = get_card(href, last_update)
            if new_card:
                cards[href] = new_card
    return cards

def print_card(item):
    print('Время публикации:', datetime.fromtimestamp(item['ts']).isoformat())
    print('Название:', item['title'])
    print('Аннотация:', item['annotation'])
    print('Автор:', item['author'])
    print()

def run_script(duration_hours):
    iteration = 1
    start_time = datetime.now()
    end_time = start_time + timedelta(hours=duration_hours)
    print(f'Время запуска скрипта: {start_time}.')
    print(f'Длительность выполнения: {duration_hours} часа.')
    print(f'Ожидаемое время окончания: {end_time}.')
    print()
    last_upd = start_time.timestamp()
    
    cards = dict()
    
    # буду брать новости про Путина и Байдена, так как встречаются чаще
    urls = ['https://ria.ru/person_Vladimir_Putin/', 'https://ria.ru/person_Dzhozef_Bajjden/']
    
    while datetime.now() < end_time:
        print(f'Итерация {iteration} началась. Последнее обновление: {datetime.fromtimestamp(last_upd).isoformat()}')
        print(f'Текущее время {datetime.now()}')
        cards = update_cards(urls, cards, last_update=last_upd)
        print('Свежие новости:')
        print()
        ts_s = []
        for key in list(cards.keys())[::-1]:
            if cards[key]['ts'] > last_upd:
                print_card(cards[key])
                ts_s.append(cards[key]['ts'])

        iteration += 1
        if ts_s:
            last_upd = max(ts_s)
        else:
            print('<Пусто>')
            print()
        time.sleep(600)

    print(f'Заключительная итерация. Последнее обновление: {datetime.fromtimestamp(last_upd).isoformat()}')
    print(f'Здесь собраны все новости до {end_time} с последнего обновления.')
    print(f'Текущее время {datetime.now()}')
    cards = update_cards(urls, cards, last_update=last_upd)
    print('Свежие новости:')
    print()
    empty_flag = True
    for key in list(cards.keys())[::-1]:
        if cards[key]['ts'] > last_upd and cards[key]['ts'] <= end_time.timestamp():
            print_card(cards[key])
            empty_flag = False
    if empty_flag:
        print('<Пусто>')
        print()
    
    print('Завершение программы...')

run_script(4)
# Out:
# Время запуска скрипта: 2024-06-04 14:25:19.841018.
# Длительность выполнения: 4 часа.
# Ожидаемое время окончания: 2024-06-04 18:25:19.841018.
#
# Итерация 1 началась. Последнее обновление: 2024-06-04T14:25:19.841018
# Текущее время 2024-06-04 14:25:19.841259
# Свежие новости:
#
# <Пусто>
#
# Итерация 2 началась. Последнее обновление: 2024-06-04T14:25:19.841018
# Текущее время 2024-06-04 14:24:18.883205
# Свежие новости:
#
# <Пусто>
#
# Итерация 3 началась. Последнее обновление: 2024-06-04T14:25:19.841018
# Текущее время 2024-06-04 14:34:47.987326
# Свежие новости:
#
# Время публикации: 2024-06-04T14:28:09
# Название: СМИ узнали о тайной сделке Байдена с Германией
# Аннотация: Президент США Джо Байден пошел на компромисс с властями Германии относительно строительства российского газопровода "Северный поток — 2", сообщает немецкая... РИА Новости, 04.06.2024
# Автор: РИА Новости
#
# Итерация 4 началась. Последнее обновление: 2024-06-04T14:28:09
# Текущее время 2024-06-04 14:45:15.148330
# Свежие новости:
#
# Время публикации: 2024-06-04T14:40:55
# Название: Эксперт рассказал об опасном для Белоруссии направлении
# Аннотация: Граница Белоруссии с Украиной на юге республики остается сложным и опасным участком из-за возможных диверсионных атак со стороны Украины, сказал РИА Новости... РИА Новости, 04.06.2024
# Автор: РИА Новости
#
# Итерация 5 началась. Последнее обновление: 2024-06-04T14:40:55
# Текущее время 2024-06-04 14:55:42.225703
# Свежие новости:
#
# Время публикации: 2024-06-04T14:53:03
# Название: СМИ пишут о тайной сделке Байдена с "немецкими друзьями" по "Севпотоку-2"
# Аннотация: Президент США Джо Байден пошел на значительные уступки властям Германии в вопросе строительства газопровода "Северный поток-2", пишет немецкая газета... Радио Sputnik, 04.06.2024
# Автор: Радио Sputnik
#
# Итерация 6 началась. Последнее обновление: 2024-06-04T14:53:03
# Текущее время 2024-06-04 15:06:05.836922
# Свежие новости:
#
# <Пусто>
#
# Итерация 7 началась. Последнее обновление: 2024-06-04T14:53:03
# Текущее время 2024-06-04 15:16:28.095666
# Свежие новости:
#
# Время публикации: 2024-06-04T15:13:15
# Название: В США предупредили о высоких рисках разрешения ударов по России
# Аннотация: Разрешение Украине использовать западное оружие для нанесения ударов вглубь территории России принесет "крайне малую выгоду" и "слишком большие риски",... РИА Новости, 04.06.2024
# Автор: Наталья Макарова
#
# Время публикации: 2024-06-04T15:13:30
# Название: США запретили Украине наносить удары ракетами ATACMS по России, пишут СМИ
# Аннотация: Вашингтон запретил Киеву наносить удары ракетами ATACMS по территории России из-за "чрезмерного страха" эскалации конфликта, передает издание Newsweek со... РИА Новости, 04.06.2024
# Автор: Дарья Буймова
#
# Итерация 8 началась. Последнее обновление: 2024-06-04T15:13:30
# Текущее время 2024-06-04 15:26:50.919599
# Свежие новости:
#
# <Пусто>
#
# Итерация 9 началась. Последнее обновление: 2024-06-04T15:13:30
# Текущее время 2024-06-04 15:37:12.787636
# Свежие новости:
#
# Время публикации: 2024-06-04T15:17:35
# Название: Байден допустил, что Украину не возьмут в НАТО
# Аннотация: Президент США Джо Байден в интервью изданию Time не исключил, что Украина останется вне НАТО после завершения текущего конфликта, но США намерены продолжить... РИА Новости, 04.06.2024
# Название: Байден назвал вступление Финляндии в НАТО своей заслугой
# Аннотация: Президент США Джо Байден в интервью изданию Time назвал собственной заслугой вступление Финляндии в НАТО. РИА Новости, 04.06.2024
# Автор: Кирилл Волков
#
# Время публикации: 2024-06-04T17:23:07
# Название: Путин обсудит с президентом Боливии включение страны в БРИКС
# Аннотация: На переговорах президента России Владимира Путина с президентом Боливии Луисом Арсе на полях ПМЭФ 6 июня будет обсуждаться вопрос включения Боливии в БРИКС,... РИА Новости, 04.06.2024
# Автор: Дарья Буймова
#
# Время публикации: 2024-06-04T17:27:03
# Название: Ушаков прокомментировал резолюцию Генассамблеи ООН по Сребренице
# Аннотация: Резолюция Генассамблеи ООН по Сребренице может усугубить существующие разногласия и увеличить конфликтный потенциал региона, сообщил журналистам помощник... РИА Новости, 04.06.2024
# Автор: Дарья Буймова
#
# Итерация 21 началась. Последнее обновление: 2024-06-04T17:27:03
# Текущее время 2024-06-04 17:40:15.593348
# Свежие новости:
#
# <Пусто>
#
# Итерация 22 началась. Последнее обновление: 2024-06-04T17:27:03
# Текущее время 2024-06-04 17:50:22.969629
# Свежие новости:
#
# Время публикации: 2024-06-04T17:43:59
# Название: Нетаньяху продолжает конфликт в Газе ради политики, считает Байден
# Аннотация: Премьер-министр Израиля Биньямин Нетаньяху может продолжать военные действия в секторе Газа из политического интереса, сообщил президент США Джо Байден в... РИА Новости, 04.06.2024
# Автор: РИА Новости
#
# Итерация 23 началась. Последнее обновление: 2024-06-04T17:43:59
# Текущее время 2024-06-04 18:00:29.093025
# Свежие новости:
#
# Время публикации: 2024-06-04T17:51:46
# Название: Гендиректор выставки "Россия" предложила сохранить наследие мероприятия
# Аннотация: Гендиректор выставки "Россия" Наталья Виртуозова представила концепцию национального центра "Россия", призванную сохранить наследие выставки и создать условия... РИА Новости, 04.06.2024
# Автор: РИА Новости
#
# Итерация 24 началась. Последнее обновление: 2024-06-04T17:51:46
# Текущее время 2024-06-04 18:10:35.891853
# Свежие новости:
#
# <Пусто>
#
# Итерация 25 началась. Последнее обновление: 2024-06-04T17:51:46
# Текущее время 2024-06-04 18:20:42.568284
# Свежие новости:
#
# Время публикации: 2024-06-04T18:14:15
# Название: Байден рассказал, как провел месяц на Украине
# Аннотация: Президент США Джо Байден в интервью изданию Time признался, что провел месяц на Украине, пока занимал кресла американского сенатора и вице-президента, и при нем РИА Новости, 04.06.2024
# Автор: РИА Новости
#
# Время публикации: 2024-06-04T18:16:11
# Название: Спецоперация, 4 июня: ВС России сбили украинский штурмовик Су-25
# Аннотация: ВСУ потеряли до 1550 военнослужащих за сутки, сбит украинский штурмовик Су-25, российские войска нанесли удар по военному объекту национальной гвардии Украины в РИА Новости, 04.06.2024
# Автор: РИА Новости
# Заключительная итерация. Последнее обновление: 2024-06-04T18:16:11
# Здесь собраны все новости до 2024-06-04 18:25:19.841018 с последнего обновления.
# Текущее время 2024-06-04 18:30:49.318611
# Свежие новости:
#
# Время публикации: 2024-06-04T18:22:02
# Название: Байден не считает предложение России по Украине лучшим вариантом для Киева
# Аннотация: Президент США Джо Байден не считает предложение России по завершению украинского конфликта лучшим вариантом для Киева на данный момент, такое мнение он выразил... РИА Новости, 04.06.2024
# Автор: РИА Новости
#
# Завершение программы...
